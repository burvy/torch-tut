# %% [markdown]
# ### Tensors

# %%
import numpy

# High dimensional array in numpy
arr = numpy.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
import torch

# High dimensional array in torch
tensor = torch.Tensor([[1,2,3],[4,5,6]])
